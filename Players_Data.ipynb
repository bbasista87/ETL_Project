# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = 'Resources/player.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file)
print(df)
# Out:
#        player_id  birth_year  birth_month  birth_day birth_country  \
# 0      aardsda01      1981.0         12.0       27.0           USA
# 1      aaronha01      1934.0          2.0        5.0           USA
# 2      aaronto01      1939.0          8.0        5.0           USA
# 3       aasedo01      1954.0          9.0        8.0           USA
# 4       abadan01      1972.0          8.0       25.0           USA
# 5       abadfe01      1985.0         12.0       17.0          D.R.
# 6      abadijo01      1854.0         11.0        4.0           USA
# 7      abbated01      1877.0          4.0       15.0           USA
# 8      abbeybe01      1869.0         11.0       11.0           USA
# 9      abbeych01      1866.0         10.0       14.0           USA
# 10     abbotda01      1862.0          3.0       16.0           USA
# 11     abbotfr01      1874.0         10.0       22.0           USA
# 12     abbotgl01      1951.0          2.0       16.0           USA
# ...

# %%
df.columns.values
# Out:
# array(['player_id', 'birth_year', 'birth_month', 'birth_day',
#        'birth_country', 'birth_state', 'birth_city', 'death_year',
#        'death_month', 'death_day', 'death_country', 'death_state',
#        'death_city', 'name_first', 'name_last', 'name_given', 'weight',
#        'height', 'bats', 'throws', 'debut', 'final_game', 'retro_id',
#        'bbref_id'], dtype=object)

# %%
df = df.drop(columns=[ 'death_year','death_month', 'death_day', 'death_country', 'death_state','death_city','name_given','retro_id','bbref_id'])

# %%
df
# Out:
#        player_id  birth_year  birth_month  birth_day birth_country  \
# 0      aardsda01      1981.0         12.0       27.0           USA
# 1      aaronha01      1934.0          2.0        5.0           USA
# 2      aaronto01      1939.0          8.0        5.0           USA
# 3       aasedo01      1954.0          9.0        8.0           USA
# 4       abadan01      1972.0          8.0       25.0           USA
# 5       abadfe01      1985.0         12.0       17.0          D.R.
# 6      abadijo01      1854.0         11.0        4.0           USA
# 7      abbated01      1877.0          4.0       15.0           USA
# 8      abbeybe01      1869.0         11.0       11.0           USA
# 9      abbeych01      1866.0         10.0       14.0           USA
# 10     abbotda01      1862.0          3.0       16.0           USA
# 11     abbotfr01      1874.0         10.0       22.0           USA
# 12     abbotgl01      1951.0          2.0       16.0           USA
# ...

# %%
debut_year= df['debut'].str[:4]
final_year= df['final_game'].str[:4]

# %%
df['debut_year']= debut_year
df['final_year']= final_year

# %%
df
# Out:
#        player_id  birth_year  birth_month  birth_day birth_country  \
# 0      aardsda01      1981.0         12.0       27.0           USA
# 1      aaronha01      1934.0          2.0        5.0           USA
# 2      aaronto01      1939.0          8.0        5.0           USA
# 3       aasedo01      1954.0          9.0        8.0           USA
# 4       abadan01      1972.0          8.0       25.0           USA
# 5       abadfe01      1985.0         12.0       17.0          D.R.
# 6      abadijo01      1854.0         11.0        4.0           USA
# 7      abbated01      1877.0          4.0       15.0           USA
# 8      abbeybe01      1869.0         11.0       11.0           USA
# 9      abbeych01      1866.0         10.0       14.0           USA
# 10     abbotda01      1862.0          3.0       16.0           USA
# 11     abbotfr01      1874.0         10.0       22.0           USA
# 12     abbotgl01      1951.0          2.0       16.0           USA
# ...

# %%
# Drop all rows with missing information
df = df.dropna(how='any')

# %%
df
# Out:
#        player_id  birth_year  birth_month  birth_day birth_country  \
# 0      aardsda01      1981.0         12.0       27.0           USA
# 1      aaronha01      1934.0          2.0        5.0           USA
# 2      aaronto01      1939.0          8.0        5.0           USA
# 3       aasedo01      1954.0          9.0        8.0           USA
# 4       abadan01      1972.0          8.0       25.0           USA
# 5       abadfe01      1985.0         12.0       17.0          D.R.
# 6      abadijo01      1854.0         11.0        4.0           USA
# 7      abbated01      1877.0          4.0       15.0           USA
# 8      abbeybe01      1869.0         11.0       11.0           USA
# 9      abbeych01      1866.0         10.0       14.0           USA
# 10     abbotda01      1862.0          3.0       16.0           USA
# 11     abbotfr01      1874.0         10.0       22.0           USA
# 12     abbotgl01      1951.0          2.0       16.0           USA
# ...

# %%
df.dtypes
# Out:
# player_id         object
# birth_year       float64
# birth_month      float64
# birth_day        float64
# birth_country     object
# birth_state       object
# birth_city        object
# name_first        object
# name_last         object
# weight           float64
# height           float64
# bats              object
# throws            object
# debut             object
# final_game        object
# debut_year        object
# final_year        object
# dtype: object

# %%
df.birth_year = df.birth_year.astype(int)
df.birth_month = df.birth_month.astype(int)
df.birth_day = df.birth_day.astype(int)
df.debut_year = df.debut_year.astype(int)
df.final_year = df.final_year.astype(int)
# Out:
# C:\Users\basis\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df.dtypes
# Out:
# player_id         object
# birth_year         int32
# birth_month        int32
# birth_day          int32
# birth_country     object
# birth_state       object
# birth_city        object
# name_first        object
# name_last         object
# weight           float64
# height           float64
# bats              object
# throws            object
# debut             object
# final_game        object
# debut_year         int32
# final_year         int32
# dtype: object

# %%
filter_df = df.loc[(df['debut_year'] > 1989)] 
player_df = filter_df.sort_values(by='player_id', ascending=False)
player_df
# Out:
#        player_id  birth_year  birth_month  birth_day birth_country  \
# 18845   zychto01        1990            8          7           USA
# 18840  zupcibo01        1966            8         18           USA
# 18839  zuninmi01        1991            3         25           USA
# 18838  zumayjo01        1984           11          9           USA
# 18837  zuletju01        1975            3         28        Panama
# 18836  zuberjo01        1969           12         10           USA
# 18834  zoskyed01        1968            2         10           USA
# 18832  zoccope01        1977            2          6           USA
# 18831  zobribe01        1981            5         26           USA
# 18828   zitoba01        1978            5         13           USA
# 18825  zinteal01        1968            5         19           USA
# 18819   zinkch01        1979            8         26           USA
# 18818  zimmery01        1984            9         28           USA
# ...
