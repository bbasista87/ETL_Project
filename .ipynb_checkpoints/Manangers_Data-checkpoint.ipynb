# %%
import pandas as pd

# %%
url = 'https://www.baseball-reference.com/managers/'

# %%
tables = pd.read_html(url)
tables
# Out:
# [      Rk                  Mgr  Yrs  From    To     W     L   W-L%  Ties  \
#  0      1           Manny Acta    6  2007  2012   372   518   .418     0
#  1      2           Bill Adair    1  1970  1970     4     6   .400     0
#  2      3           Joe Adcock    1  1967  1967    75    87   .463     0
#  3      4             Bob Addy    2  1875  1877     8    23   .258     0
#  4      5            Bob Allen    2  1890  1900    87    87   .500     5
#  5      6         Doug Allison    1  1873  1873     2    21   .087     0
#  6      7         Sandy Alomar    1  2012  2012     3     3   .500     0
#  7      8          Felipe Alou   14  1992  2006  1033  1021   .503     1
#  8      9    Walter Alston HOF   23  1954  1976  2040  1613   .558     5
#  9     10        Joe Altobelli    7  1977  1991   437   407   .518     0
#  10    11      Joey Amalfitano    3  1979  1981    66   116   .363     3
#  11    12  Sparky Anderson HOF   26  1970  1995  2194  1834   .545     2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5b530f533b78> in <module>()
# ----> 1 tables.head
#
# AttributeError: 'list' object has no attribute 'head'
