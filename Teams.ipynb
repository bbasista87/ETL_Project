# %%
import pandas as pd
import os
import csv
import matplotlib

# %%
file_teams = "Resources/Teams.csv"

df_teams = pd.read_csv(file_teams)

delete_df= df_teams.drop(columns=["R", "AB","H","2B","3B","HR","BB","SO","SB","CS",
             "HBP","SF","RA","ER","ERA","CG","SHO","SV","IPouts","HA","HRA","BBA","SOA","E","DP","FP"])

#reducing in this dataframe didn't get rid of the extra columns
#reduced_teams = df_teams.loc[:, ["yearID","lgID","teamID","franchID","divID","Rank","G","Ghome","W", "L","DivWin",
                        #"WCWin", "LgWin", "WSWin", "name","park","attendance", "BPF",
                        #"PPF","teamIDBR","teamIDlahman45","teamIDretro"]]

delete_df

final_teams_df = delete_df.loc[(
    delete_df['yearID'] >= 1990)]

# %%
final_teams_df
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  \
# 2047    1990   NL    ATL      ATL     W     6  162   81.0   65   97
# 2048    1990   AL    BAL      BAL     E     5  161   80.0   76   85
# 2049    1990   AL    BOS      BOS     E     1  162   81.0   88   74
# 2050    1990   AL    CAL      ANA     W     4  162   81.0   80   82
# 2051    1990   AL    CHA      CHW     W     2  162   80.0   94   68
# 2052    1990   NL    CHN      CHC     E     4  162   81.0   77   85
# 2053    1990   NL    CIN      CIN     W     1  162   81.0   91   71
# 2054    1990   AL    CLE      CLE     E     4  162   81.0   77   85
# 2055    1990   AL    DET      DET     E     3  162   81.0   79   83
# 2056    1990   NL    HOU      HOU     W     4  162   81.0   75   87
# 2057    1990   AL    KCA      KCR     W     6  161   81.0   75   86
# 2058    1990   NL    LAN      LAD     W     2  162   81.0   86   76
# 2059    1990   AL    MIN      MIN     W     7  162   81.0   74   88
# 2060    1990   AL    ML4      MIL     E     6  162   81.0   74   88
# 2061    1990   NL    MON      WSN     E     3  162   81.0   85   77
# 2062    1990   AL    NYA      NYY     E     7  162   81.0   67   95
# 2063    1990   NL    NYN      NYM     E     2  162   81.0   91   71
# 2064    1990   AL    OAK      OAK     W     1  162   81.0  103   59
# 2065    1990   NL    PHI      PHI     E     4  162   81.0   77   85
# 2066    1990   NL    PIT      PIT     E     1  162   81.0   95   67
# 2067    1990   NL    SDN      SDP     W     4  162   81.0   75   87
# 2068    1990   AL    SEA      SEA     W     5  162   81.0   77   85
# 2069    1990   NL    SFN      SFG     W     3  162   81.0   85   77
# 2070    1990   NL    SLN      STL     E     6  162   81.0   70   92
# 2071    1990   AL    TEX      TEX     W     3  162   82.0   83   79
# 2072    1990   AL    TOR      TOR     E     2  162   81.0   86   76
# 2073    1991   NL    ATL      ATL     W     1  162   81.0   94   68
# 2074    1991   AL    BAL      BAL     E     6  162   81.0   67   95
# 2075    1991   AL    BOS      BOS     E     2  162   81.0   84   78
# 2076    1991   AL    CAL      ANA     W     7  162   81.0   81   81
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ...  ...
# 2805    2016   NL    ARI      ARI     W     4  162   81.0   69   93
# 2806    2016   NL    ATL      ATL     E     5  161   81.0   68   93
# 2807    2016   AL    BAL      BAL     E     2  162   81.0   89   73
# 2808    2016   AL    BOS      BOS     E     1  162   81.0   93   69
# 2809    2016   AL    CHA      CHW     C     4  162   81.0   78   84
# 2810    2016   NL    CHN      CHC     C     1  162   81.0  103   58
# 2811    2016   NL    CIN      CIN     C     5  162   81.0   68   94
# 2812    2016   AL    CLE      CLE     C     1  161   80.0   94   67
# 2813    2016   NL    COL      COL     W     3  162   81.0   75   87
# 2814    2016   AL    DET      DET     C     2  161   81.0   86   75
# 2815    2016   AL    HOU      HOU     W     3  162   81.0   84   78
# 2816    2016   AL    KCA      KCR     C     3  162   81.0   81   81
# 2817    2016   AL    LAA      ANA     W     4  162   81.0   74   88
# 2818    2016   NL    LAN      LAD     W     1  162   81.0   91   71
# 2819    2016   NL    MIA      FLA     E     3  161   80.0   79   82
# 2820    2016   NL    MIL      MIL     C     4  162   81.0   73   89
# 2821    2016   AL    MIN      MIN     C     5  162   81.0   59  103
# 2822    2016   AL    NYA      NYY     E     4  162   81.0   84   78
# 2823    2016   NL    NYN      NYM     E     2  162   81.0   87   75
# 2824    2016   AL    OAK      OAK     W     5  162   81.0   69   93
# 2825    2016   NL    PHI      PHI     E     4  162   81.0   71   91
# 2826    2016   NL    PIT      PIT     C     3  162   81.0   78   83
# 2827    2016   NL    SDN      SDP     W     5  162   81.0   68   94
# 2828    2016   AL    SEA      SEA     W     2  162   81.0   86   76
# 2829    2016   NL    SFN      SFG     W     2  162   81.0   87   75
# 2830    2016   NL    SLN      STL     C     2  162   81.0   86   76
# 2831    2016   AL    TBA      TBD     E     5  162   81.0   68   94
# 2832    2016   AL    TEX      TEX     W     1  162   81.0   95   67
# 2833    2016   AL    TOR      TOR     E     2  162   81.0   89   73
# 2834    2016   NL    WAS      WSN     E     1  162   81.0   95   67
#
#          ...     LgWin WSWin                           name  \
# 2047     ...         N     N                 Atlanta Braves
# 2048     ...         N     N              Baltimore Orioles
# 2049     ...         N     N                 Boston Red Sox
# 2050     ...         N     N              California Angels
# 2051     ...         N     N              Chicago White Sox
# 2052     ...         N     N                   Chicago Cubs
# 2053     ...         Y     Y                Cincinnati Reds
# 2054     ...         N     N              Cleveland Indians
# 2055     ...         N     N                 Detroit Tigers
# 2056     ...         N     N                 Houston Astros
# 2057     ...         N     N             Kansas City Royals
# 2058     ...         N     N            Los Angeles Dodgers
# 2059     ...         N     N                Minnesota Twins
# 2060     ...         N     N              Milwaukee Brewers
# 2061     ...         N     N                 Montreal Expos
# 2062     ...         N     N               New York Yankees
# 2063     ...         N     N                  New York Mets
# 2064     ...         Y     N              Oakland Athletics
# 2065     ...         N     N          Philadelphia Phillies
# 2066     ...         N     N             Pittsburgh Pirates
# 2067     ...         N     N               San Diego Padres
# 2068     ...         N     N               Seattle Mariners
# 2069     ...         N     N           San Francisco Giants
# 2070     ...         N     N            St. Louis Cardinals
# 2071     ...         N     N                  Texas Rangers
# 2072     ...         N     N              Toronto Blue Jays
# 2073     ...         Y     N                 Atlanta Braves
# 2074     ...         N     N              Baltimore Orioles
# 2075     ...         N     N                 Boston Red Sox
# 2076     ...         N     N              California Angels
# ...      ...       ...   ...                            ...
# 2805     ...         N     N           Arizona Diamondbacks
# 2806     ...         N     N                 Atlanta Braves
# 2807     ...         N     N              Baltimore Orioles
# 2808     ...         N     N                 Boston Red Sox
# 2809     ...         N     N              Chicago White Sox
# 2810     ...         Y     Y                   Chicago Cubs
# 2811     ...         N     N                Cincinnati Reds
# 2812     ...         Y     N              Cleveland Indians
# 2813     ...         N     N               Colorado Rockies
# 2814     ...         N     N                 Detroit Tigers
# 2815     ...         N     N                 Houston Astros
# 2816     ...         N     N             Kansas City Royals
# 2817     ...         N     N  Los Angeles Angels of Anaheim
# 2818     ...         N     N            Los Angeles Dodgers
# 2819     ...         N     N                  Miami Marlins
# 2820     ...         N     N              Milwaukee Brewers
# 2821     ...         N     N                Minnesota Twins
# 2822     ...         N     N               New York Yankees
# 2823     ...         N     N                  New York Mets
# 2824     ...         N     N              Oakland Athletics
# 2825     ...         N     N          Philadelphia Phillies
# 2826     ...         N     N             Pittsburgh Pirates
# 2827     ...         N     N               San Diego Padres
# 2828     ...         N     N               Seattle Mariners
# 2829     ...         N     N           San Francisco Giants
# 2830     ...         N     N            St. Louis Cardinals
# 2831     ...         N     N                 Tampa Bay Rays
# 2832     ...         N     N                  Texas Rangers
# 2833     ...         N     N              Toronto Blue Jays
# 2834     ...         N     N           Washington Nationals
#
#                                park attendance  BPF  PPF  teamIDBR  \
# 2047  Atlanta-Fulton County Stadium   980129.0  105  106       ATL
# 2048               Memorial Stadium  2415189.0   97   98       BAL
# 2049                 Fenway Park II  2528986.0  105  105       BOS
# 2050                Anaheim Stadium  2555688.0   97   97       CAL
# 2051                  Comiskey Park  2002357.0   98   98       CHW
# 2052                  Wrigley Field  2243791.0  108  108       CHC
# 2053             Riverfront Stadium  2400892.0  105  105       CIN
# 2054              Cleveland Stadium  1225240.0  100  100       CLE
# 2055                  Tiger Stadium  1495785.0  101  102       DET
# 2056                      Astrodome  1310927.0   97   98       HOU
# 2057                 Royals Stadium  2244956.0   98   98       KCR
# 2058                 Dodger Stadium  3002396.0   98   97       LAD
# 2059    Hubert H Humphrey Metrodome  1751584.0  107  107       MIN
# 2060                 County Stadium  1752900.0   99   99       MIL
# 2061                Stade Olympique  1373087.0   96   96       MON
# 2062              Yankee Stadium II  2006436.0  100  102       NYY
# 2063                   Shea Stadium  2732745.0  100   99       NYM
# 2064               Oakland Coliseum  2900217.0   96   95       OAK
# 2065               Veterans Stadium  1992484.0   99  100       PHI
# 2066           Three Rivers Stadium  2049908.0   96   95       PIT
# 2067            Jack Murphy Stadium  1856396.0  101  101       SDP
# 2068                       Kingdome  1509727.0  101  101       SEA
# 2069               Candlestick Park  1975528.0   96   96       SFG
# 2070               Busch Stadium II  2573225.0  100  100       STL
# 2071              Arlington Stadium  2057911.0  100  101       TEX
# 2072                        Skydome  3885284.0  106  105       TOR
# 2073  Atlanta-Fulton County Stadium  2140217.0  106  106       ATL
# 2074               Memorial Stadium  2552753.0   96   97       BAL
# 2075                 Fenway Park II  2562435.0  105  105       BOS
# 2076                Anaheim Stadium  2416236.0   99  100       CAL
# ...                             ...        ...  ...  ...       ...
# 2805                    Chase Field  2036216.0  107  108       ARI
# 2806                   Turner Field  2020914.0  102  104       ATL
# 2807    Oriole Park at Camden Yards  2172344.0  101  101       BAL
# 2808                 Fenway Park II  2955434.0  108  106       BOS
# 2809            U.S. Cellular Field  1746293.0   96   97       CHW
# 2810                  Wrigley Field  3232420.0   95   93       CHC
# 2811       Great American Ball Park  1894085.0   99  100       CIN
# 2812              Progressive Field  1591667.0  110  109       CLE
# 2813                    Coors Field  2602524.0  117  117       COL
# 2814                  Comerica Park  2493859.0  101  101       DET
# 2815               Minute Maid Park  2306623.0   90   89       HOU
# 2816               Kauffman Stadium  2557712.0  105  106       KCR
# 2817       Angel Stadium of Anaheim  3016142.0   95   95       LAA
# 2818                 Dodger Stadium  3703312.0   93   92       LAD
# 2819                   Marlins Park  1712417.0   93   93       MIA
# 2820                    Miller Park  2314614.0   99   99       MIL
# 2821                   Target Field  1963912.0   96   98       MIN
# 2822             Yankee Stadium III  3063405.0  105  105       NYY
# 2823                     Citi Field  2789602.0  102  102       NYM
# 2824                  O.co Coliseum  1521506.0   90   91       OAK
# 2825             Citizens Bank Park  1915144.0   91   93       PHI
# 2826                       PNC Park  2249201.0  100  101       PIT
# 2827                     Petco Park  2351422.0   99   99       SDP
# 2828                   Safeco Field  2267928.0   98   97       SEA
# 2829                      AT&T Park  3365256.0  103  102       SFG
# 2830              Busch Stadium III  3444490.0  100   99       STL
# 2831                Tropicana Field  1286163.0   93   94       TBR
# 2832  Rangers Ballpark in Arlington  2710402.0  106  105       TEX
# 2833                  Rogers Centre  3392099.0  111  110       TOR
# 2834                 Nationals Park  2481938.0  100   98       WSN
#
#       teamIDlahman45 teamIDretro
# 2047             ATL         ATL
# 2048             BAL         BAL
# 2049             BOS         BOS
# 2050             CAL         CAL
# 2051             CHA         CHA
# 2052             CHN         CHN
# 2053             CIN         CIN
# 2054             CLE         CLE
# 2055             DET         DET
# 2056             HOU         HOU
# 2057             KCA         KCA
# 2058             LAN         LAN
# 2059             MIN         MIN
# 2060             MIL         MIL
# 2061             MON         MON
# 2062             NYA         NYA
# 2063             NYN         NYN
# 2064             OAK         OAK
# 2065             PHI         PHI
# 2066             PIT         PIT
# 2067             SDN         SDN
# 2068             SEA         SEA
# 2069             SFN         SFN
# 2070             SLN         SLN
# 2071             TEX         TEX
# 2072             TOR         TOR
# 2073             ATL         ATL
# 2074             BAL         BAL
# 2075             BOS         BOS
# 2076             CAL         CAL
# ...              ...         ...
# 2805             ARI         ARI
# 2806             ATL         ATL
# 2807             BAL         BAL
# 2808             BOS         BOS
# 2809             CHA         CHA
# 2810             CHN         CHN
# 2811             CIN         CIN
# 2812             CLE         CLE
# 2813             COL         COL
# 2814             DET         DET
# 2815             HOU         HOU
# 2816             KCA         KCA
# 2817             ANA         ANA
# 2818             LAN         LAN
# 2819             FLO         MIA
# 2820             ML4         MIL
# 2821             MIN         MIN
# 2822             NYA         NYA
# 2823             NYN         NYN
# 2824             OAK         OAK
# 2825             PHI         PHI
# 2826             PIT         PIT
# 2827             SDN         SDN
# 2828             SEA         SEA
# 2829             SFN         SFN
# 2830             SLN         SLN
# 2831             TBA         TBA
# 2832             TEX         TEX
# 2833             TOR         TOR
# 2834             MON         WAS
#
# [788 rows x 22 columns]

# %%
final_teams_df.to_csv(final_teams_df, encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d29b1e2b3a46> in <module>()
# ----> 1 final_teams_df.to_csv(final_teams, encoding='utf-8', index=False)
#
# NameError: name 'final_teams' is not defined
